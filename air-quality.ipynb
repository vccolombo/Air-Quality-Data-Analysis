# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("AirQualityUCI.csv", delimiter=';', decimal=",")
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 17 columns):
# Date             9357 non-null object
# Time             9357 non-null object
# CO(GT)           9357 non-null float64
# PT08.S1(CO)      9357 non-null float64
# NMHC(GT)         9357 non-null float64
# C6H6(GT)         9357 non-null float64
# PT08.S2(NMHC)    9357 non-null float64
# NOx(GT)          9357 non-null float64
# PT08.S3(NOx)     9357 non-null float64
# NO2(GT)          9357 non-null float64
# PT08.S4(NO2)     9357 non-null float64
# PT08.S5(O3)      9357 non-null float64
# T                9357 non-null float64
# RH               9357 non-null float64
# AH               9357 non-null float64
# Unnamed: 15      0 non-null float64
# Unnamed: 16      0 non-null float64
# dtypes: float64(15), object(2)
# memory usage: 1.2+ MB

# %%
# remover colunas adicionais que não tem nenhuma entrada
df = df.drop(columns=['Unnamed: 15', 'Unnamed: 16'])

# remover data e horário
df = df.drop(columns=["Date", "Time"])

# %%
# descobrir quantos valores são nulos
df.isnull().sum()
# Out:
# CO(GT)           114
# PT08.S1(CO)      114
# NMHC(GT)         114
# C6H6(GT)         114
# PT08.S2(NMHC)    114
# NOx(GT)          114
# PT08.S3(NOx)     114
# NO2(GT)          114
# PT08.S4(NO2)     114
# PT08.S5(O3)      114
# T                114
# RH               114
# AH               114
# dtype: int64

# %%
df = df.dropna() # retirar todas as linhas que tenham entradas nulas
# Verificar se retirou os nulos
df.isnull().sum()
# Out:
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
# Visualizar quais colunas tem dados faltando (-200 de acordo com a documentação)
df = df.replace(-200, np.nan)

df.isnull().sum()
# Out:
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %%
# Retirar linhas em que AH é nan
df = df.dropna(subset=["AH"])
df.isnull().sum()
# Out:
# CO(GT)           1647
# PT08.S1(CO)         0
# NMHC(GT)         8104
# C6H6(GT)            0
# PT08.S2(NMHC)       0
# NOx(GT)          1595
# PT08.S3(NOx)        0
# NO2(GT)          1598
# PT08.S4(NO2)        0
# PT08.S5(O3)         0
# T                   0
# RH                  0
# AH                  0
# dtype: int64

# %%
# Remover coluna com quase todos os dados faltando
df = df.drop(columns=["NMHC(GT)"])

# substituir o resto pela média
col = "CO(GT)"
df[col] = df[col].fillna((df[col].mean()))

# col = "PT08.S1(CO)"
# df[col] = df[col].fillna((df[col].mean()))

# col = "C6H6(GT)"
# df[col] = df[col].fillna((df[col].mean()))

# col = "PT08.S2(NMHC)"
# df[col] = df[col].fillna((df[col].mean()))

col = "NOx(GT)"
df[col] = df[col].fillna((df[col].mean()))

# col = "PT08.S3(NOx)"
# df[col] = df[col].fillna((df[col].mean()))

col = "NO2(GT)"
df[col] = df[col].fillna((df[col].mean()))

# col = "PT08.S4(NO2)"
# df[col] = df[col].fillna((df[col].mean()))

# col = "PT08.S5(O3)"
# df[col] = df[col].fillna((df[col].mean()))

# col = "T"
# df[col] = df[col].fillna((df[col].mean()))

df.isnull().sum()
# Out:
# CO(GT)           0
# PT08.S1(CO)      0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     C6H6(GT)  PT08.S2(NMHC)      NOx(GT)  \
# count  8991.000000  8991.000000  8991.000000    8991.000000  8991.000000
# mean      2.129711  1099.833166    10.083105     939.153376   242.189292
# std       1.298237   217.080037     7.449820     266.831429   187.117216
# min       0.100000   647.000000     0.100000     383.000000     2.000000
# 25%       1.200000   937.000000     4.400000     734.500000   112.000000
# 50%       2.129711  1063.000000     8.200000     909.000000   227.000000
# 75%       2.600000  1231.000000    14.000000    1116.000000   280.000000
# max      11.900000  2040.000000    63.700000    2214.000000  1479.000000
#
#        PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)            T  \
# count   8991.000000  8991.000000   8991.000000  8991.000000  8991.000000
# mean     835.493605   112.145137   1456.264598  1022.906128    18.317829
# std      256.817320    43.189073    346.206794   398.484288     8.832116
# ...

# %%
# Remove possible outliers
q = df.quantile(0.99)
df = df[df < q]

q = df.quantile(0.01)
df = df[df > q]

df = df.dropna()

df
# Out:
#       CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  \
# 0        2.6       1360.0      11.9         1046.0    166.0        1056.0
# 1        2.0       1292.0       9.4          955.0    103.0        1174.0
# 2        2.2       1402.0       9.0          939.0    131.0        1140.0
# 3        2.2       1376.0       9.2          948.0    172.0        1092.0
# 4        1.6       1272.0       6.5          836.0    131.0        1205.0
# ...      ...          ...       ...            ...      ...           ...
# 9350     5.0       1446.0      22.4         1362.0    586.0         415.0
# 9351     3.9       1297.0      13.6         1102.0    523.0         507.0
# 9352     3.1       1314.0      13.5         1101.0    472.0         539.0
# 9353     2.4       1163.0      11.4         1027.0    353.0         604.0
# 9354     2.4       1142.0      12.4         1063.0    293.0         603.0
#
#       NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# ...

# %%
normalized_df=(df-df.mean())/df.std()
normalized_df["AH"] = df["AH"]

normalized_df
# Out:
#         CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)   NOx(GT)  PT08.S3(NOx)  \
# 0     0.483145     1.363088  0.330473       0.460527 -0.421920      1.097946
# 1    -0.075773     1.009364 -0.063508       0.074866 -0.823379      1.650015
# 2     0.110533     1.581564 -0.126545       0.007057 -0.644953      1.490944
# 3     0.110533     1.446317 -0.095026       0.045199 -0.383686      1.266374
# 4    -0.448385     0.905328 -0.520526      -0.429461 -0.644953      1.795050
# ...        ...          ...       ...            ...       ...           ...
# 9350  2.718815     1.810445  1.985195       1.799748  2.254473     -1.901001
# 9351  1.694133     1.035373  0.598381       0.697857  1.853014     -1.470575
# 9352  0.948909     1.123804  0.582621       0.693619  1.528023     -1.320861
# 9353  0.296839     0.338329  0.251677       0.380004  0.769712     -1.016756
# 9354  0.296839     0.229091  0.409270       0.532574  0.387370     -1.021434
#
# ...

# %%
import seaborn as sns
# calculate the correlation matrix
corr = normalized_df.corr()
corr
# Out:
#                  CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)   NOx(GT)  \
# CO(GT)         1.000000     0.769280  0.818730       0.809817  0.701919
# PT08.S1(CO)    0.769280     1.000000  0.862214       0.867603  0.592948
# C6H6(GT)       0.818730     0.862214  1.000000       0.988097  0.585735
# PT08.S2(NMHC)  0.809817     0.867603  0.988097       1.000000  0.579024
# NOx(GT)        0.701919     0.592948  0.585735       0.579024  1.000000
# PT08.S3(NOx)  -0.653086    -0.771915 -0.764717      -0.801065 -0.617924
# NO2(GT)        0.617319     0.536198  0.515211       0.532730  0.728847
# PT08.S4(NO2)   0.536215     0.629579  0.749116       0.752796  0.119438
# PT08.S5(O3)    0.753514     0.875949  0.842550       0.850906  0.685737
# T              0.040528     0.042845  0.240855       0.265377 -0.252119
# RH            -0.003907     0.079204 -0.121146      -0.145150  0.184157
# AH             0.033288     0.108105  0.172895       0.178489 -0.141233
#
# ...

# %%
# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %%
# Temperature
import matplotlib.pyplot as plt
x = normalized_df["T"]
y = df["AH"]
plt.scatter(x, y)
plt.xlabel("Temperature (celsius)")
plt.ylabel("Absolute Humidity")
# Out:
# Text(0, 0.5, 'Absolute Humidity')

# %%
# PT08.S4(NO2)
import matplotlib.pyplot as plt
x = normalized_df["PT08.S4(NO2)"]
y = df["AH"]
plt.scatter(x, y)
plt.xlabel("PT08.S4(NO2)")
plt.ylabel("Absolute Humidity")
# Out:
# Text(0, 0.5, 'Absolute Humidity')
